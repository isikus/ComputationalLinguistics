# %% [markdown]
# # Семинар 3. Исправление опечаток

# %%
import os, re
from string import punctuation
import numpy as np
import json
from collections import Counter
from pprint import pprint
punct = set(punctuation)
from sklearn.metrics import classification_report

# %% [markdown]
# Возьмем данные с соревнования Dialog Evaluation 2015 по исправлению опечаток. Данные представляют собой набор предложений (правильное - ошибочное). Задача найти слова с ошибками и заменить их на правильный вариант.
#
# Недостатком тут является то, что не всегда можно правильно сопоставить слова правильного предложения и ошибочного (из-за слов с пропущенным или добавленным пробелом). Из статьи авторов корпуса не очень понятно, как они решали эту проблему, поэтому я просто удалил все такие предложения.

# %%
bad = open('sents_with_mistakes.txt', encoding='utf8').read().splitlines()
true = open('correct_sents.txt', encoding='utf8').read().splitlines()

# %%
# Посмотрим на пары предложений
print(bad[2])
print(true[2])
# Out:
# Пояним эту мысль.
# Поясним эту мысль

# %%
# напишем функцию, которая будет сопоставлять слова в правильном и ошибочном варианте
# разобьем предложение по пробелам и удалим пунктуация на границах слов
def align_words(sent_1, sent_2):
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()
    
    tokens_1 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_1 if (set(token)-punct)]
    tokens_2 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_2 if (set(token)-punct)]
    
    return list(zip(tokens_1, tokens_2))

# %%
pprint(align_words(true[1], bad[1]))
# Out:
# [('апофеозом', 'опофеозом'),
#  ('дня', 'дня'),
#  ('для', 'для'),
#  ('меня', 'меня'),
#  ('сегодня', 'сегодня'),
#  ('стала', 'стала'),
#  ('фраза', 'фраза'),
#  ('услышанная', 'услышанная'),
#  ('в', 'в'),
#  ('новостях', 'новостях')]

# %% [markdown]
# Вытащим только неправильные варианты и заодно посчитаем процент ошибок.

# %%
mistakes = []
total = 0

for i in range(len(true)):
    
    word_pairs = align_words(true[i], bad[i])
    
    for pair in word_pairs:
        if pair[0] != pair[1]:
            mistakes.append(pair)
        
        total += 1

# %%
print('Доля ошибок - ', len(mistakes)/total )
# Out:
# Доля ошибок -  0.13034358769476628

# %%
mistakes[:5]
# Out:
# [('симпатичнейшее', 'симпатичнейшое'),
#  ('апофеозом', 'опофеозом'),
#  ('поясним', 'пояним'),
#  ('получатся', 'полчатся'),
#  ('очень', 'оччччень')]

# %% [markdown]
# Обернем в Counter, чтобы сразу увидеть частотные ошибки.

# %%
Counter(mistakes).most_common(10)
# Out:
# [(('сегодня', 'седня'), 24),
#  (('вообще', 'вобще'), 18),
#  (('вообще', 'ваще'), 17),
#  (('естественно', 'естесственно'), 17),
#  (('хочется', 'хочеться'), 16),
#  (('кстати', 'кстате'), 16),
#  (('очень', 'ооочень'), 14),
#  (('как-то', 'както'), 9),
#  (('очень', 'оооочень'), 9),
#  (('это', 'ето'), 9)]

# %% [markdown]
# Из-за того, что процент ошибок довольно низкий, не очень выгодно будет находить исправление для каждого слова. Нужен какой-то более простой классификатор, который выделит ошибочные слова, чтобы потом только их и редактировать.

# %% [markdown]
# Самый простой способ это сделать - составить словарь правильных слов и потом сравнивать с ним. Чтобы не делать этого вручную, можно взять какой-нибудь корпус текстов, прошедщих редактуру. Новостные тексты для этого хорошо подходят.

# %% [markdown]
# Я заранее собрал небольшой корпус новостных текстов и немного почистил его удалив отдельную пунктуацию и пунктуацию на границах слов.

# %%
corpus = open('corpus_ng.txt', encoding='utf8').read().splitlines()

# %%
# нормализация нам тут не нужна так как нужно находить слова в разных формах
print(corpus[1].split()[:10])
# Out:
# ['судя', 'по', 'всему', 'русская', 'православная', 'церковь', 'нашла', 'долгожданную', 'национальную', 'идею']

# %% [markdown]
# ## Задание 1.
# Напишите функцию, которая будет предсказывать ошибочные слова на основе корпуса.

# %%
corpus[2]
# Out:
# 'буду краток одиссей хоть и был туристом но никогда не писал на скалах фразы вроде здесь был одя потому что за такие художества морской бог посейдон мог и трезубцем заехать а одиссей не оскорблял чувства богов и верующих в них граждан губернатор алтайского края александр карлин согласен с греческим героем местные энтузиасты даже реализуют проект чистые скалы  достояние алтая очищая горы от надписей а то многие как остап бендер всюду норовят оставить память о себе в виде надписей типа киса и ося здесь были губернатор карлин не разделяет подобных порывов а про своего коллегу не называя его рассказал следующую историю был александр богданович с женой в карловых варах и там рассказывает губернатор есть очень достойный памятник  он посвящен членам правящей династии романовых которые побывали в этих местах я читаю все имена продолжает карлин и ниже списка  фамилию моего коллеги он не из царской семьи у него простая фамилия и исполнено это чуть-чуть посолиднее чем здесь был вася карлин по его словам спросил этого своего неназванного коллегу кто мол над ним так пошутил почему пошутил удивился коллега это я и пояснил свои действия они там были написали и я там был а почему буквы-то кривые  спросил напоследок александр богданович как мог как мог  ответил коллега наши губернаторы  они хоть и не все из правящей династии но что-то царственное в них есть и искусство любят как могут так и украшают действительность и это правильно экологи-энтузиасты в крайнем случае все отмоют и исправят политические и прочие ошибки в наскальной и иной живописи наших чиновников а то ишь'

# %%
# создайте множество, чтобы проверять вхождения
vocab = set()

## ваш код здесь
for body in corpus:
    newset = set(body.split())
    vocab = vocab|newset

# %%
def predict_mistaken(word, vocab):
    '''
    ::input: word, vocabulary
    ::output: 1 or 0
    
    '''
    ## ваш код здесь
    return 1 * (word not in vocab)

# %%
vocab
# Out:
# {'выучат',
#  'отныне',
#  'сословия',
#  'австрийской',
#  'вдохновенный',
#  '2015-м',
#  'набравшей',
#  'инцидентах',
#  'неправ',
#  'недовыработка',
#  'номиналу',
#  'накладные',
#  'планирования',
#  'уронившие',
#  'меняющих',
#  'интересовала',
#  'сбегал',
#  'кривулина',
#  'общалась',
#  'резкую',
#  'предложено',
#  'компьютеров',
#  '554',
#  'ввт',
#  'облегчение',
#  'отложено',
#  'небывалые',
#  'встретятся',
#  'боголепова',
#  'спинку',
#  'пагубной',
#  'продления',
#  'округ',
#  'пигментных',
#  'ловли',
#  'белобандитов',
#  'обособленности',
#  'выделяем',
#  'иранцами',
#  'самозапись',
#  'вышке',
#  'engagement',
#  'норвегией',
#  'окаменевшем',
#  'маститых',
#  'домогательств',
#  'тарасова',
#  'иллюстраций',
#  'подотраслях',
#  'известнейших',
#  'пакт',
#  'металлист',
#  'слетел',
#  'спэни',
#  'мосфильма',
#  'ненавистью',
#  'проникшись',
#  'зеллнеры',
#  'комплиментом',
#  'дисперсно',
#  'дополнить',
#  'бишкеке',
#  'знамен',
#  'предпринимательская',
#  'рассматривалась',
#  'юго-западному',
#  'каширке',
#  'матушке',
#  'ата-мекен',
#  'внимающая',
#  'паузой',
#  'проверю',
#  'самосознанию',
#  'различное',
#  'расположения',
#  'дрыхни',
#  'союзе',
#  'затих',
#  'апостолу',
#  'очных',
#  'забрать',
#  'серию',
#  'вишневский',
#  'вейнингер',
#  'коррупционный',
#  'ibcs',
#  'алави',
#  '88,7',
#  'лузеров',
#  '3066',
#  'деморализации',
#  'трехмерная',
#  'боестолкновения',
#  'картельного',
#  'включенными',
#  'пежо',
#  'хлынувшего',
#  'инбер',
#  'барбары',
#  'бесконтактная',
#  'единые',
#  'перегружают',
#  'дизайнерская',
#  'поклониться',
#  'мюнхена',
#  'налей',
#  'комментарийной',
#  'суджашвили',
#  'военнослужащие',
#  'завоевывали',
#  'республиканской',
#  'белым',
#  'потребоваться',
#  'освоенную',
#  'грожана',
#  'креативный',
#  'неуклюжее',
#  'одноступенчатого',
#  'выстраиванию',
#  'запорожье',
#  'капеллана',
#  'предпринимательством',
#  'нарисованная',
#  'закрытому',
#  'доставлен',
#  'нараспах',
#  'уговаривал',
#  'размагничивание',
#  'препятствовали',
#  'поборника',
#  'вычегдой',
#  'аргентинской',
#  'артака',
#  'насосных',
#  'малыш',
#  'издательств',
#  'веществ',
#  'вызывающие',
#  'зарисовкам',
#  'толпа',
#  'рыбака-контрабандиста',
#  'предусматривающих',
#  'активируя',
#  'старинный',
#  'остающуюся',
#  'гомеопатию',
#  'саров',
#  'разведчика',
#  'строившей',
#  'носящей',
#  'подонок',
#  'бальбек',
#  'даваат',
#  'демократию',
#  'эмоционально',
#  'портвейна',
#  'вспомогательные',
#  'поклонялась',
#  'элина',
#  'республика–ата–журт',
#  'завершающая',
#  'придавленное',
#  'роге',
#  'впились',
#  'биттерлемон',
#  'аэс',
#  'действовавшие',
#  'консолидировавшихся',
#  'посягательство',
#  '1846',
#  'пажити',
#  'случись',
#  'народным',
#  'плита',
#  'дер',
#  'оксид',
#  'спикеру',
#  'толчком',
#  'одежда',
#  'оптимистичное',
#  'проявлен',
#  'успех',
#  'дающее',
#  'встречающиеся',
#  'энергосбережение',
#  'причастный',
#  'услышали',
#  'фукусимы',
#  'последующий',
#  'данелии',
#  'лоскутком',
#  'порожденный',
#  'орудия',
#  'иностранном',
#  'пыхтит',
#  'балансировала',
#  'фруктовый',
#  'быке',
#  'кроато',
#  'столкнется',
#  'одиночном',
#  'понадобятся',
#  'honda',
#  'инакомыслия',
#  'финансировании',
#  'ощутил',
#  'политического',
#  'защелачивание',
#  'разрекламированная',
#  'областные',
#  'преображен',
#  'обустроена',
#  'графом',
#  'грассирующий',
#  'гарику',
#  'розовом',
#  'пленив',
#  'stratos',
#  'являла',
#  'метаэтического',
#  'сдпк',
#  'патриоты',
#  'предсмертного',
#  'двухпалатный',
#  'кондратия',
#  'ашхабад',
#  'уменьшится',
#  'прекрасной',
#  'железная',
#  'улучшенной',
#  'лекарств-дженериков',
#  'священнодействуй',
#  'германо-советской',
#  'повернутое',
#  'низкоэмиссионных',
#  'борисоглебском',
#  'кэ',
#  'нелогичность',
#  'сиддхардхе',
#  'кази-кумух',
#  'двухдневным',
#  'картине',
#  'передняя',
#  '03.11.17',
#  'задуманный',
#  'оформлять',
#  'опиум',
#  'бабушки',
#  'экологический',
#  'вылетел',
#  'учащением',
#  'дружески',
#  'секундахособой',
#  'нема',
#  'освободит',
#  'монархий',
#  'византийскому',
#  'гози',
#  'песнь',
#  'вытеснению',
#  'абулгазиев',
#  'подавшие',
#  'гайдой',
#  'двигался',
#  'телеграмму',
#  'жанетта',
#  'поднимали',
#  'имитацией',
#  'slon',
#  'городским',
#  'ленинградском',
#  'салонной',
#  'лентяю',
#  'black',
#  'футбольном',
#  'соперниками',
#  'упредить',
#  'капитанская',
#  'секулярны',
#  'обгоном',
#  'усомнились',
#  'предусмотренные',
#  'колебаниям',
#  'переданных',
#  'стариком',
#  'календаря',
#  'околополитической',
#  'сплетниц',
#  'смирнова',
#  'авиле',
#  'сербская',
#  'посланием',
#  'диссертационной',
#  'обряда',
#  'кельям',
#  'эксплуатация',
#  'напряжения',
#  'конкурирующим',
#  'владикавказа',
#  'сумасшествий',
#  'написанных',
#  'лыжники',
#  'лишения',
#  'едином',
#  '86-миллионного',
#  'гидравлически',
#  'абрис',
#  'несвойственная',
#  'богатств',
#  'аум',
#  'предупреждали',
#  'крокодилам',
#  'аллее',
#  'давешней',
#  'воцерковлению',
#  'важнейшие',
#  'культурных',
#  'малость',
#  'подробна',
#  'богопротивных',
#  'приписаны',
#  'коллегами',
#  'чуа',
#  'напомнят',
#  'утренней',
#  'вставок-флэшбеков',
#  'ненаглядная',
#  'судостроительной',
#  'бабник',
#  'terminator',
#  'уаза',
#  'господь',
#  'твердой',
#  'сырьевой',
#  'дримкастах',
#  'кинули',
#  'безвременья',
#  'натуральное',
#  'перечня',
#  'названные',
#  'перья',
#  'гоголю',
#  '2,5–3',
#  'моногородах',
#  'величайших',
#  'собранными',
#  'японо-американский',
#  'пало-альто',
#  'сравнивались',
#  'формулировало',
#  'применят',
#  'подводная',
#  'сконцентрировать',
#  'превалирует',
#  'изучения',
#  'по-удмуртски',
#  'зачтет',
#  'поговорку',
#  'потребителю',
#  'истребителя',
#  'курия',
#  'дверь',
#  'хочешь',
#  'большевикам',
#  'лазурита',
#  'обыгравших',
#  'ежевечернее',
#  'дождевых',
#  'еженедельную',
#  'минздраве',
#  'депортирован',
#  'соседками',
#  'вертикальными',
#  'обмолвилась',
#  'показываешь',
#  'картины',
#  'голодала',
#  'абонементного',
#  'сообразить',
#  'давиташвили',
#  'мышь',
#  'понемножку',
#  'вспомнится',
#  'утилизационные',
#  'благородие',
#  'категориям',
#  'накопилась',
#  'нанести',
#  'уговору',
#  'контрабанда',
#  'чувствовался',
#  'помериться',
#  'детством',
#  'подозрительный',
#  'арбалета',
#  'песня',
#  'промоутера',
#  'сесиашвили',
#  'замещая',
#  'неразрывной',
#  'конвоирами',
#  'познакомиться',
#  'знающий',
#  'биткойна',
#  'завышенных',
#  'азиаты',
#  'набирал',
#  'суфизма',
#  'хлопок',
#  'дипломатом',
#  'вложиться',
#  'техниках',
#  'ясности',
#  'обескураживающим',
#  'пластикой',
#  'газовая',
#  'милая',
#  'дагестанской',
#  'антитеррористические',
#  'форматам',
#  'поэтапным',
#  'спасательным',
#  'моргана',
#  'обгоны',
#  '14,5',
#  'номерной',
#  'вольт',
#  'бредень',
#  'увлечениях',
#  'рубцы',
#  'научно-техническому',
#  'обиняками',
#  'посредственные',
#  'оды',
#  'darеes',
#  'проснулась',
#  'разлагать',
#  'манежная',
#  'театроль',
#  'сдамся',
#  'шатается',
#  'искушение',
#  'британца',
#  'застенок',
#  'котельные',
#  'камбодже',
#  'однородного',
#  'выступы',
#  'открывающегося',
#  'почитаются',
#  'полуулыбке',
#  'перерастает',
#  'констатация',
#  'вошедшая',
#  'территорию',
#  'почувствовало',
#  'стилизаторами',
#  'арене',
#  'слэйтер',
#  'посвящалась',
#  'салатах',
#  'грузинским',
#  'выражены',
#  'капиталистическую',
#  'отчизна',
#  'обработка',
#  'оной',
#  'мерой',
#  'театрально-культурного',
#  'мусорного',
#  'коркер',
#  'лохи',
#  'ультимативных',
#  'беспечить',
#  'перчатка',
#  'черепаха',
#  'этаким',
#  'жалуются',
#  'компромиссных',
#  'сказанного',
#  'юркие',
#  'кут-эль-амар',
#  'подъем',
#  'избавилось',
#  'раненых',
#  'израиль–кипр',
#  'экстремальный',
#  'наименьшему',
#  'объединены',
#  'премьер-министру',
#  'отложить',
#  'ташкенте',
#  'разогревая',
#  'окрас',
#  'паспорта',
#  'февраля',
#  'экономику',
#  'дэнам',
#  'смыслу',
#  'задворках',
#  'улыбок',
#  'sola',
#  'использовалась',
#  'обмыть',
#  'проконтролировать',
#  'рав',
#  'начинаете',
#  'замечено',
#  'явное',
#  'пользовалась',
#  'акрама',
#  'базой',
#  'старение',
#  'публикуют',
#  'турецким',
#  'газетной',
#  'генпрокуратура',
#  'двойственность',
#  'пропагандировать',
#  'виолончелистка',
#  'инициатива',
#  'незнакомки',
#  'золотых',
#  'непрерывным',
#  'каб-1500л',
#  'читала',
#  'наскочил',
#  'молодцом',
#  'веду',
#  '01.03.18',
#  'предосторожности',
#  'оправдывает',
#  'спбгу',
#  'полезные',
#  'неработающая',
#  'перегибают',
#  'жаловались',
#  'франциска',
#  'руководствами',
#  'долю',
#  'королевство',
#  'фоновых',
#  'возродиться',
#  'карикатурных',
#  'поощрял',
#  'базируясь',
#  'регламентированным',
#  'семинаристом',
#  'полетят',
#  'грациозности',
#  'рисковать',
#  'free',
#  'караси',
#  'возрастут',
#  'изенгарда',
#  'исповедовал',
#  'рубрики',
#  '880',
#  'волновалась',
#  'стирание',
#  'талац',
#  'застопорился',
#  'сепаратистскими',
#  'немцу',
#  'по-любому',
#  'избиратели',
#  'аксюта',
#  'хранилищу',
#  'измерить',
#  'блеклые',
#  'отжимался',
#  'беспроводная',
#  'обратные',
#  'формируемая',
#  'сдерживающему',
#  'возможно',
#  'нарезка',
#  'розыску',
#  'великобритания–сша',
#  'требовании',
#  'победные',
#  'касается',
#  'пригрозил',
#  'суру',
#  'непредвиденного',
#  'автомобилестроителей',
#  'помпадур',
#  'затронуты',
#  'смотрелся',
#  'сочетающем',
#  'спинозы',
#  'нажав',
#  'огненными',
#  'fxpro',
#  'кремний',
#  'кидается',
#  'сгорит',
#  'зарезавшему',
#  'борьбе',
#  'этическом',
#  'sdb',
#  'музейщикам',
#  'су-24',
#  'нессара',
#  'военные',
#  'к-9',
#  'коллектива',
#  'матфею',
#  'цифровым',
#  'сокрушительную',
#  'обезлюдевшими',
#  'подвижников',
#  'постный',
#  'романсов',
#  'дистанций',
#  'тлело',
#  'ярких',
#  'литвы',
#  'ладони',
#  'шансов',
#  'рублях',
#  '52',
#  'гасан',
#  'удаленную',
#  'авторские',
#  'пароход',
#  'индийским',
#  'открытом',
#  'океанология',
#  'российско-вьетнамском',
#  'генеральную',
#  'зверски',
#  'пассау',
#  'эллинги',
#  'дрэгон',
#  'тронов',
#  'фокса',
#  'бумажный',
#  'куликовым',
#  'кольчуге',
#  'заберем',
#  'либералам',
#  'согласовывают',
#  'мобильным',
#  'аргентиной',
#  'молчаливее',
#  'транспортных',
#  'неделе',
#  'характером',
#  'кибиров',
#  'замаранная',
#  'позвякивание',
#  'интересные',
#  'погонные',
#  'чп',
#  'сочным',
#  'обочины',
#  'отчего',
#  'храме',
#  'пронзительные',
#  'приобретены',
#  'авральном',
#  'неприменение',
#  'корона',
#  'прощупать',
#  'погибает',
#  'пшеница',
#  'собственности',
#  'рейган',
#  'кашу',
#  'расширенном',
#  'крестьянка',
#  'псевдопалимпсест',
#  'глиноземном',
#  'постоктябрьской',
#  'загримированная',
#  'лишенная',
#  'отличиях',
#  'снежинку',
#  'девичьи',
#  'отраженье',
#  'пародистами',
#  'запустила',
#  'инициировало',
#  'сакелларидис',
#  'выполнимой',
#  'зрелищнее',
#  'каракачанов',
#  'четыре',
#  'азимой',
#  'оскорбление',
#  'автомобилистам',
#  'улыбнувшись',
#  'анзор',
#  'bundesanstalt',
#  'подтверждая',
#  'теплоход',
#  'насыщенным',
#  'экзамена',
#  'мамочка',
#  'перечислять',
#  'полуоборота',
#  'вылепим',
#  'заводах',
#  'пласты',
#  'неразведанным',
#  'скончавшимся',
#  'всесторонний',
#  'сложную',
#  'рейтингования',
#  'экранизировали',
#  'подумывал',
#  'сокрушается',
#  'умеренная',
#  'планета',
#  'клопы',
#  'двусмысленные',
#  'строительно-монтажными',
#  'хозяйственниками',
#  'либерально-глобалистских',
#  'взаимосвязям',
#  'мигрантов',
#  'комплектовании',
#  'подвергая',
#  'пренебрежительный',
#  'оправдание',
#  'синтетических',
#  'разрушили',
#  'уверить',
#  'ускоренная',
#  'тактического',
#  'исландией',
#  'плохими',
#  'мухи',
#  'такие',
#  'мегаватт-час',
#  'george',
#  'кончаловский',
#  'артикулируемой',
#  'удается',
#  'светлановым',
#  'дельфинарий',
#  'окруженца',
#  'предвиденным',
#  'хорош',
#  'тунгусскую',
#  'тащит',
#  'уберут',
#  'рыбцов',
#  'разведывательно-ударные',
#  'репортерам',
#  'расторгнет',
#  'системообразующих',
#  'цифровыми',
#  'герцога',
#  'инаду',
#  'концерту-воссоединению',
#  'гидрологических',
#  'аналогично',
#  'военнопленными',
#  'аральск',
#  'инициированные',
#  'разлезалась',
#  'обманчивое',
#  'евросоюз',
#  'комфортнее',
#  'оставила',
#  'эммы',
#  'медведя',
#  'комплексе',
#  'сектантскому',
#  'императиве',
#  'елочку',
#  'объявлении',
#  'фосфоритов',
#  '978-5-93381-377-4',
#  'положениями',
#  'уле',
#  'грицман',
#  'сходному',
#  'обладающих',
#  'оборонной',
#  'одноэтажных',
#  'болельщики',
#  'мозговая',
#  'мадрида',
#  'денежные',
#  'выразившееся',
#  'определяются',
#  'материк',
#  'палка',
#  'суннитские',
#  'третьяковская',
#  'катастрофически',
#  'заводоуправление',
#  'благоустроили',
#  'джексон',
#  'полутысячи',
#  'анонсирован',
#  'гренинг',
#  'энграма',
#  'беспочвенность',
#  'обыденное',
#  'мучительно',
#  'умножении',
#  'удерживаются',
#  'госрасходы',
#  'поставившим',
#  'альянсы',
#  'рослый',
#  'бац',
#  'фиксирует',
#  'хашим',
#  'репутацией',
#  'беспокоило',
#  'полчищ',
#  'концерну',
#  'сторожем',
#  'томимая',
#  'первопонятия',
#  'механизации',
#  'интернет-сериала',
#  'интервью',
#  'москва–орск',
#  'излечилась',
#  'законтрактованных',
#  'кошек',
#  'находила',
#  'швецу',
#  'рудн',
#  'произведенных',
#  'электронно-лучевых',
#  'аб',
#  'вмешательств',
#  'прошутто',
#  'бизнес-клубе',
#  'включены',
#  'марксизму',
#  'усугубления',
#  'джинн',
#  'крыма-sos',
#  'пушкиной',
#  'пацифистской',
#  'пассажиропотока',
#  'публичности',
#  'продемонстрировало',
#  'прецеденту',
#  'янина',
#  'иуды',
#  'малайская',
#  'партнерскую',
#  'галльский',
#  'колымским',
#  'земляков-имамов',
#  'пополнит',
#  'луга',
#  'вузам',
#  'многостанчников',
#  'интенсификации',
#  'астане',
#  'мулино-2',
#  'собирать',
#  'представляю',
#  'лоренцо',
#  'распорядиться',
#  'juniper',
#  'располагать',
#  'относились',
#  'звукозаписывающие',
#  'возделать',
#  'плакали',
#  'закончились',
#  'колокольня',
#  'львы',
#  'раскрывает',
#  'аршановский',
#  'диавол',
#  'полномасштабно',
#  'доработке',
#  'подали',
#  'волошинским',
#  'обманывали',
#  'медиками',
#  'заклятых',
#  'бобслей',
#  'плачущим',
#  'пузыревский',
#  'артрозы',
#  'хоффман',
#  'принимаются',
#  'serebro',
#  'певцу',
#  'переживают',
#  'тан',
#  'петлиным',
#  'гондурасской',
#  'совершивший',
#  'заявила',
#  'давке',
#  'майдане',
#  'багулалы',
#  'issues',
#  'повышением',
#  'портфельных',
#  'выживая',
#  'обезболивающие',
#  '111',
#  'пересекающий',
#  'хлынину',
#  'недобрую',
#  'танцоров',
#  'композиторских',
#  'магией',
#  '3d',
#  'делле',
#  'описывают',
#  'главах',
#  'глубокой',
#  'устремлены',
#  'влажные',
#  'горизонтального',
#  'лакмусовой',
#  'рейсовом',
#  'формируемое',
#  'войдут',
#  'приведением',
#  'томаса',
#  'родина',
#  'всб',
#  'разгорался',
#  'перепроизводством',
#  'эксклюзивную',
#  'годов',
#  'издательствами',
#  'ловцами',
#  'ликвидировано',
#  'интерлагоса',
#  'бойега',
#  'общность',
#  'важность',
#  'попробуешь',
#  'нарыв',
#  'сотворчества',
#  'эру',
#  'пресс-центр',
#  'чирикание',
#  'уровнем',
#  'контактов',
#  'тургеневские',
#  'бумага',
#  'автодорогу',
#  'санкциям',
#  'лишнего',
#  'способу',
#  'пузырьков',
#  'п.п',
#  'савин',
#  'создавемый',
#  'минитмен-3',
#  'увенчаны',
#  'офисные',
#  'запечатан',
#  'энергоэффективностью',
#  'ноу-хау',
#  'цэгмид',
#  'пришельца-веверлея',
#  'лавке',
#  'грамма',
#  'дезорганизован',
#  'изабелле',
#  'газировкой',
#  'накладывается',
#  'технологическим',
#  'действительностью',
#  'согбенного',
#  'сожрать',
#  'примате',
#  'возвратиться',
#  'колбасы',
#  'хранилищ',
#  'теснились',
#  'медленными',
#  'аюто',
#  'центральноазиатскими',
#  'перес',
#  'тортом',
#  'возглас',
#  'синагогам',
#  'сорос',
#  'замечательного',
#  'woods-hole',
#  '1420',
#  'полупатриархальную',
#  'озадачил',
#  'арфы',
#  'рок-звезд',
#  'затратные',
#  'ячейки',
#  'савонаролы',
#  'участвовавшей',
#  ...}

# %%
# для оценки создайте два списка y_true и y_pred
# пройдитесь по предложениям
# сопоставите слова с помощью функции align_words
# пройдитесь по парам слов и
# если слова одинаковые добавьте в y_true 0 
# если слова разные добавьте в y_true 1
# предскажите ошибочность слова из bad списка 
# добавьте предсказание в список y_pred

y_true = []
y_pred = []

## ваш код здесь
for correct, wrong in zip(true, bad):
    pairs = align_words(correct, wrong)
    
    for correct_word, wrong_word in pairs:
        
        if correct_word == wrong_word:
            y_true.append(0)
        else:
            y_true.append(1)
        
        pred = predict_mistaken(wrong_word, vocab)
        y_pred.append(pred)

# %%
# оцените качество с помощью classification_report
print(classification_report(y_true, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.89      0.93      8707
#           1       0.55      0.88      0.68      1305
#
# avg / total       0.92      0.89      0.90     10012

# %% [markdown]
# ### Генерация исправлений

# %% [markdown]
# Теперь нужно думать о том, как исправить неправильные слова. Посмотрим как это можно делать на примере известной реализации Питера Норвига.

# %% [markdown]
# Основная идея - сделать словарь правильных слов (у нас уже есть), расчитать вероятность каждого слова в корпусе.

# %%
corpus = [sent.split() for sent in open('corpus_ng.txt', encoding='utf8').read().splitlines()]
WORDS = Counter()
for sent in corpus:
    WORDS.update(sent)

# %%
WORDS.most_common(10)
# Out:
# [('в', 67679),
#  ('и', 55933),
#  ('на', 27860),
#  ('не', 21627),
#  ('что', 18299),
#  ('с', 18224),
#  ('по', 13117),
#  ('а', 9696),
#  ('как', 8958),
#  ('к', 8907)]

# %%
# фунцкия расчета вероятности слова
N = sum(WORDS.values())
def P(word, N=N): 
    "Вычисляем вероятность слова"
    return WORDS[word] / N

# %%
P('апофеоз')
# Out:
# 1.8025455548325345e-06

# %% [markdown]
# Чтобы найти исправления нужно сгенерировать возможные исправления и выбрать те, которые есть в словаре. Если есть несколько вариантов, то выбрать тот, у котогоро наибольшая вероятность.

# %%
def correction(word): 
    "Находим наиболее вероятное похожее слово"
    return max(candidates(word), key=P)

def candidates(word): 
    "Генерируем кандидатов на исправление"
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    "Выбираем слова, которые есть в корпусе"
    return set(w for w in words if w in WORDS)

def edits1(word):
    "Создаем кандидатов, которые отличаются на одну букву"
    letters    = 'йцукенгшщзхъфывапролджэячсмитьбюё'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "Создаем кандидатов, которые отличаются на две буквы"
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
# %%time
correction('слива')
# Out:
# Wall time: 0 ns
# 'слова'

# %% [markdown]
# Давайте поподробнее разберем, что происходит в функции edits.

# %%
word = 'опефеоз'
splits = [(word[:i], word[i:])    for i in range(len(word) + 1)]

# %%
splits[:10]
# Out:
# [('', 'опефеоз'),
#  ('о', 'пефеоз'),
#  ('оп', 'ефеоз'),
#  ('опе', 'феоз'),
#  ('опеф', 'еоз'),
#  ('опефе', 'оз'),
#  ('опефео', 'з'),
#  ('опефеоз', '')]

# %%
deletes = [L + R[1:] for L, R in splits if R]

# %%
deletes[:10]
# Out:
# ['пефеоз', 'оефеоз', 'опфеоз', 'опееоз', 'опефоз', 'опефез', 'опефео']

# %%
transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]

# %%
transposes[:10]
# Out:
# ['поефеоз', 'оепфеоз', 'опфееоз', 'опеефоз', 'опефоез', 'опефезо']

# %%
letters    = 'йцукенгшщзхъфывапролджэячсмитьбюё'
replaces = [L + c + R[1:] for L, R in splits if R for c in letters]

# %%
len(replaces)
# Out:
# 231

# %%
inserts = [L + c + R for L, R in splits for c in letters]

# %%
inserts[:10]
# Out:
# ['йопефеоз',
#  'цопефеоз',
#  'уопефеоз',
#  'копефеоз',
#  'еопефеоз',
#  'нопефеоз',
#  'гопефеоз',
#  'шопефеоз',
#  'щопефеоз',
#  'зопефеоз']

# %% [markdown]
# Для оценки используем просто долю правильных исправлений.

# %%
# До этого мы уже считали долю ошибок во всех предложениях.
# Поэтому если ничего не менять то доля правильных исправлений уже будет 100 - 13 = 87 %.
# Наш подход соответственно должен показывать лучший результат 
correct = 0
total = 0

for i in range(len(true)):
    word_pairs = align_words(true[i], bad[i])
    
    for pair in word_pairs:
        
        predicted = correction(pair[1])
        if predicted == pair[0]:
            correct += 1
        total += 1
    if not i % 10:
        print(i)
        print(correct/total)
# Out:
# 0
# 0.7333333333333333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-eb613e7e7e76> in <module>()
#      10     for pair in word_pairs:
#      11
# ---> 12         predicted = correction(pair[1])
#      13         if predicted == pair[0]:
#      14             correct += 1
#
# <ipython-input-22-8d3479327353> in correction(word)
#       1 def correction(word):
#       2     "Находим наиболее вероятное похожее слово"
# ----> 3     return max(candidates(word), key=P)
#       4
#       5 def candidates(word):
#
# <ipython-input-22-8d3479327353> in candidates(word)
#       5 def candidates(word):
#       6     "Генерируем кандидатов на исправление"
# ----> 7     return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])
#       8
#       9 def known(words):
#
# <ipython-input-22-8d3479327353> in known(words)
#       9 def known(words):
#      10     "Выбираем слова, которые есть в корпусе"
# ---> 11     return set(w for w in words if w in WORDS)
#      12
#      13 def edits1(word):
#
# <ipython-input-22-8d3479327353> in <genexpr>(.0)
#       9 def known(words):
#      10     "Выбираем слова, которые есть в корпусе"
# ---> 11     return set(w for w in words if w in WORDS)
#      12
#      13 def edits1(word):
#
# <ipython-input-22-8d3479327353> in <genexpr>(.0)
#      23 def edits2(word):
#      24     "Создаем кандидатов, которые отличаются на две буквы"
# ---> 25     return (e2 for e1 in edits1(word) for e2 in edits1(e1))
#
# KeyboardInterrupt:

# %%
print(correct/total)
# Out:
# 0.8620689655172413

# %%
# %%time
correction('нав')
# Out:
# Wall time: 0 ns
# 'на'

# %%
# %%time
correction('насмехатьсяаававттававаываываы')
# Out:
# Wall time: 5.56 s
# 'насмехатьсяаававттававаываываы'

# %% [markdown]
# Посмотрим какие исправления выбираются для самых частотных опечаток.

# %%
[(wt[0], wt[1], correction(wt[1])) for wt, _ in Counter(mistakes).most_common(10)]
# Out:
# [('сегодня', 'седня', 'сеня'),
#  ('вообще', 'вобще', 'вообще'),
#  ('вообще', 'ваще', 'ваще'),
#  ('естественно', 'естесственно', 'естественно'),
#  ('хочется', 'хочеться', 'хочется'),
#  ('кстати', 'кстате', 'кстати'),
#  ('очень', 'ооочень', 'очень'),
#  ('как-то', 'както', 'какао'),
#  ('очень', 'оооочень', 'оооочень'),
#  ('это', 'ето', 'ето')]

# %% [markdown]
# ### Метрики близости слов.

# %% [markdown]
# Вместо того, чтобы генерировать все варианты, можно искать похожие слова в словаре. Для этого нужно задать метрику похожести. Для исправления опечаток часто используются расстояния редактирования (количество редактирований, которые нужно сделать в строке a, чтобы прийти к b.

# %%
# в питоне есть библиотеке для нахождения близких строк

# %%
from difflib import get_close_matches

# %%
# %%time
get_close_matches('опофеоз', WORDS.keys(), n=1)
# Out:
# Wall time: 1.42 s
# ['апофеоз']

# %% [markdown]
# Работает тоже не очень быстро.

# %% [markdown]
# Недавно вышла библиотека, в которой реализованы многие методы нахождения расстояний.

# %%
# !pip install textdistance
# Out:
# Requirement already satisfied: textdistance in c:\users\ivan\anaconda3\lib\site-packages
# You are using pip version 9.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import textdistance

# %%
def get_closest_match_with_metric(text, lookup, metric=textdistance.levenshtein):
    similarities = Counter()
    for word in lookup:
        similarities[word] = metric.normalized_similarity(text, word) 
    
    return similarities.most_common(1)[0]

# %%
# %%time
get_closest_match_with_metric('опофиоз', WORDS, textdistance.hamming)
# Out:
# Wall time: 5.66 s
# ('апофеоз', 0.7142857142857143)

# %%
# %%time
get_closest_match_with_metric('апофиоз', WORDS, textdistance.levenshtein)
# Out:
# Wall time: 1min 2s
# ('апофеоз', 0.8571428571428572)

# %% [markdown]
# Ждать так долго мы не можем, поэтому попробуем что-то побыстрее.

# %% [markdown]
# Многие вещи, которые медленно решаются в питоне, можно оптимизировать с помощью матричных и векторных операций.

# %% [markdown]
# Сделаем поиск похожих по векторам символов, из которых состоит слово.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances

# %%
corpus = [sent.split() for sent in open('corpus_ng.txt', encoding='utf8').read().splitlines()]
WORDS = Counter()
for sent in corpus:
    WORDS.update(sent)

# %%
vocab = list(WORDS.keys())
id2word = {i:word for i, word in enumerate(vocab)}

vec = CountVectorizer(analyzer='char', ngram_range=(1,1))
X = vec.fit_transform(vocab)

# %%
def get_closest_match_vec(text, X, vec, TOPN=10):
    v = vec.transform([text])
    similarities = cosine_distances(v, X)
    topn = similarities.argsort()[0][:TOPN]
    
    return [id2word[top] for top in topn]

# %%
# %%time
get_closest_match_vec('опофеоз', X, vec)
# Out:
# Wall time: 63 ms
# ['апофеозом',
#  'апофеоз',
#  'шизофреноподобное',
#  'полезного',
#  'позволено',
#  'профсоюзного',
#  'позором',
#  'золотое',
#  'розовое',
#  'половое']

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# Напишите функцию, которая принимает слово и находит ближайшее к нему в словаре (сгенерируйте несколько кандидатов с помощью get_closest_match_vec, а затем посчитайте метрики близости до кадого слова и выведете самое близкое).

# %%
def get_closest_hybrid_match(text, X, vec, metric=textdistance.levenshtein):
    Suggestions = get_closest_match_vec(text, X, vec, TOPN=10)
    closest = get_closest_match_with_metric(text, Suggestions, textdistance.levenshtein)[0]
    
    
    return closest

# %%
get_closest_hybrid_match('алкогнль', X, vec)
# Out:
# 'алкоголь'

# %%
# %%time

# Если ничего не менять, то доля правильных исправлений уже будет 100 - 13 = 87 %.
# Старый подход
correct = 0
total = 0

for i in range(len(true)):
    word_pairs = align_words(true[i], bad[i])
    
    for pair in word_pairs:
        
        predicted = correction(pair[1])
        if predicted == pair[0]:
            correct += 1
        total += 1
    if not i % 100:
        print(i)
        print(correct/total)
# Out:
# 0
# 0.7333333333333333
# 100
# 0.8512544802867383
# 200
# 0.8581048581048581
# 300
# 0.859375
# 400
# 0.8619809788912085
# 500
# 0.8610698365527489
# 600
# 0.8622976098689283
# 700
# 0.8622047244094488
# 800
# 0.8594993655554274
# 900
# 0.8596669374492283
# Wall time: 5min 23s

# %%
print("Resulting method accuracy:", "{:.2f}".format(100*correct/total)+"%")
# Out:
# Resulting method accuracy: 86.02%

# %%
# %%time

# Если ничего не менять, то доля правильных исправлений уже будет 100 - 13 = 87 %.
# Новый подход
new_correct = 0
new_total = 0

for i in range(len(true)):
    word_pairs = align_words(true[i], bad[i])
    
    for pair in word_pairs:
        
        predicted = get_closest_hybrid_match(pair[1], X, vec)
        if predicted == pair[0]:
            new_correct += 1
        new_total += 1
    if not i % 100:
        print(i)
        print(new_correct/new_total)
# Out:
# 0
# 0.5333333333333333
# 100
# 0.8243727598566308
# 200
# 0.8316498316498316
# 300
# 0.8347355769230769
# 400
# 0.8366968220830434
# 500
# 0.8380386329866271
# 600
# 0.8390131071703932
# 700
# 0.8385826771653543
# 800
# 0.8352751182373976
# 900
# 0.8362103980503656
# Wall time: 11min 3s

# %%
print("Resulting method accuracy:", "{:.2f}".format(100*new_correct/new_total)+"%")
# Out:
# Resulting method accuracy: 83.66%

# %% [markdown]
# В рассмотренных методах при выборе исправления никак не использовался контекст. Про то как это можно сделать, можно почитать вот тут - https://habr.com/ru/post/346618/

# %%
# method enhansion is yet to come
